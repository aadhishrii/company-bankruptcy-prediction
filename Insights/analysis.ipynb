# %% [markdown]
# ## Financial Ratios
#
# Debt to equity = total liabilities/total equity
#
# Buffett likes to see a ratio of under 0.5 here. This helps him avoid companies that are likely to get into trouble during economic downturns.
#
# Current ratio = current assets/current liabilities
#
# Buffett likes to see a current ratio of at least 1.5. In other words, if a company always receives more cash than it pays out, it can always meet its short-term debt obligations in time.
#
# Return on equity = net income/total equity
#
# Buffett likes to see a consistent ROE ratio of at least 8% over a 10-year period. This indicates that the company is consistently making a decent profit with the earnings that management retains.
#
# Quick Ratio = (Current Assets – Inventory) / Current Liabilities
#
# Should be higher than 1.
#
# Profit margin = Profit / Revenue
#
# a good profit margin will typically fall between 5% and 10%.

# %% [markdown]
# ### Infosys
#
# Current Ratio:
#
# 2019 → 2.55
#
# 2020 → 1.74
#
# 2021 → 1.67
#
# The current ratio is well above 1.5 which indicates this company receives more cash than it pays out
#
# But over the last two years we can see that this ratio has been decreasing which is not a good sign as this means that the liabilities are increasing at a much faster rate as compared to the assets
#
# Return on equity:
#
# 2019 → 0.23
#
# 2020 → 0.25
#
# 2021 → 0.25
#
# This ratio his well above 0.08 which indicates this company is making decent profits over the past 3 years
#
# Debt to Equity:
#
# 2019 → 0.29
#
# 2020 → 0.39
#
# 2021 → 0.40
#
# All the ratios are below 0.5 which is a good sign
#
# But in 2021 the value is 0.4 which is very close to 0.5 and this is not a good thing as if it touches 0.5 there is a chance that this company will get into trouble during economic downturns

# %% [markdown]
# ### Nestle
#
# Current Ratio:
#
# 2019 → 2.83
#
# 2020 → 2.61
#
# 2021 → 2.54
#
# The current ratio is well above 1.5 which indicates this company receives more cash than it pays out
#
# But over the last two years we can see that this ratio has been decreasing which is not a good sign as this means that the liabilities are increasing at a much faster rate as compared to the assets
#
# Return on equity:
#
# 2019 → 0.43
#
# 2020 → 1.02
#
# 2021 → 1.03
#
# This ratio his well above 0.08 which indicates this company is making decent profits over the past 3 years
#
# Debt to Equity:
#
# 2019 → 1.20
#
# 2020 → 2.73
#
# 2021 → 2.91
#
# All the ratios are below 0.5 which is a good sign
#
# But in 2021 the value is 0.4 which is very close to 0.5 and this is not a good thing as if it touches 0.5 there is a chance that this company will get into trouble during economic downturns
